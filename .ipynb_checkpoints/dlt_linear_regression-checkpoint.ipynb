# %% [raw]
# #version 1.0
# #2017/5/22

# %%
# %matplotlib inline
from sklearn import linear_model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Data preprocess

# %%
data = pd.read_csv("data/del_interpolation.csv")
data = data.fillna(0)

# %%
total_num = len(data)
test_num = np.int(0.005 * total_num)

# %%
train = data[-480:-48]
test = data[-48:]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 8304 to 8735
# Data columns (total 14 columns):
# datetime           432 non-null object
# AMB_TEMP           432 non-null float64
# PM2.5              432 non-null float64
# RAINFALL           432 non-null float64
# RH                 432 non-null float64
# WIND_SPEED         432 non-null float64
# WS_HR              432 non-null float64
# DLT_AMB_TEMP       432 non-null float64
# DLT_RAINFALL       432 non-null float64
# DLT_RH             432 non-null float64
# DLT_WIND_SPEED     432 non-null float64
# DLT_WS_HR          432 non-null float64
# DLT_PM2.5          432 non-null float64
# LAST_HOUR_PM2.5    432 non-null float64
# dtypes: float64(13), object(1)
# memory usage: 47.3+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 8736 to 8783
# Data columns (total 14 columns):
# datetime           48 non-null object
# AMB_TEMP           48 non-null float64
# PM2.5              48 non-null float64
# RAINFALL           48 non-null float64
# RH                 48 non-null float64
# WIND_SPEED         48 non-null float64
# WS_HR              48 non-null float64
# DLT_AMB_TEMP       48 non-null float64
# DLT_RAINFALL       48 non-null float64
# DLT_RH             48 non-null float64
# DLT_WIND_SPEED     48 non-null float64
# DLT_WS_HR          48 non-null float64
# DLT_PM2.5          48 non-null float64
# LAST_HOUR_PM2.5    48 non-null float64
# dtypes: float64(13), object(1)
# memory usage: 5.3+ KB

# %%
columns = data.columns
features = [f for f in columns if f not in ['datetime', 'PM2.5', 'LAST_HOUR_PM2.5', 'DLT_PM2.5']]
print features
# Out:
# ['AMB_TEMP', 'RAINFALL', 'RH', 'WIND_SPEED', 'WS_HR', 'DLT_AMB_TEMP', 'DLT_RAINFALL', 'DLT_RH', 'DLT_WIND_SPEED', 'DLT_WS_HR']

# %%
X_train, y_train = train[features], train['DLT_PM2.5']
X_test, y_test = test[features], test['DLT_PM2.5']

# %% [markdown]
# # Linear Regression

# %%
regr = linear_model.LinearRegression(normalize=True)
regr.fit(X_train, y_train)
print 'Coefficients: \n', regr.coef_
# Out:
# Coefficients:
# [-0.1982152  -0.81504931 -0.02460075 -0.02317328 -0.14666014  0.55737964
#   1.03290565  0.29228343  0.17973409 -0.60223018]

# %%
y_predict = regr.predict(X_test)

# %% [markdown]
# # Result

# %%
#print y_predict, y_test

# %% [markdown]
# # Plot

# %%
predict_max = max(y_predict)
test_max = max(y_test)
both_max = max(predict_max, test_max)
predict_min = min(y_predict)
test_min = min(y_test)
both_min = min(predict_min, test_min)

# %%
plt.rcParams['figure.figsize'] = [16.0, 8.0]
plt.xlabel("Index")
plt.ylabel("Value")
y_predict = [round(y, 1) for y in y_predict]
y_test_round = [round(y, 1) for y in y_test]
plt.plot(y_predict, color="red", label="Predict")
plt.plot(y_test_round, color="blue", label="Real")
plt.legend(loc='upper left')
plt.show()

# %%
plt.rcParams['figure.figsize'] = [16.0, 8.0]
plt.xlabel('Predict')
plt.ylabel('Real')
plt.plot(y_predict, y_test, 'ro')
plt.plot([both_min, both_max], [both_min, both_max])
plt.show()

# %% [markdown]
# # Measure

# %%
print("Mean squared error: %.4f"
      % mean_squared_error(y_predict, y_test))
# Out:
# Mean squared error: 14.8881
