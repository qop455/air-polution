# %%
import graphlab as gl
import datetime as dt

# %%
def add_time_interval(ts, colname):
    lastcol = ts.column_names()[-1]
    ts.add_column(ts.shift(steps=1)[lastcol], name=colname)
    return ts

# %%
date_feature = gl.SFrame.read_csv("../data/interpolated.csv")
date_feature['datetime'] = date_feature['datetime'].apply(lambda x: dt.datetime.strptime(x, "%Y-%m-%d %H:%M:%S"))
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to qop455.iim05g@nctu.edu.tw and will expire on June 23, 2018.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1498547627.log
# Finished parsing file /Users/jason/Desktop/air-polution/data/interpolated.csv
# Parsing completed. Parsed 100 lines in 0.047236 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,float,float,float,float,float,float,float,float,float,float,float,float,float,float,float]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /Users/jason/Desktop/air-polution/data/interpolated.csv
# Parsing completed. Parsed 8784 lines in 0.040206 secs.

# %%
ts = gl.TimeSeries(date_feature, index='datetime')
ts = ts[['PM2.5']]

#ts['dlt'] = ts['PM2.5'] - ts.shift(steps=1)['PM2.5']
ts.head()
# Out:
# Columns:
# 	datetime	datetime
# 	PM2.5	float
#
# Rows: 10
#
# Data:
# +---------------------+-------+
# |       datetime      | PM2.5 |
# +---------------------+-------+
# | 2016-01-01 00:00:00 |  66.0 |
# | 2016-01-01 01:00:00 |  56.0 |
# | 2016-01-01 02:00:00 |  57.0 |
# | 2016-01-01 03:00:00 |  65.0 |
# | 2016-01-01 04:00:00 |  67.0 |
# | 2016-01-01 05:00:00 |  61.0 |
# | 2016-01-01 06:00:00 |  42.0 |
# | 2016-01-01 07:00:00 |  38.0 |
# | 2016-01-01 08:00:00 |  39.0 |
# | 2016-01-01 09:00:00 |  43.0 |
# +---------------------+-------+
# [10 rows x 2 columns]

# %%
interval = 24
for i in range(interval):
    colname = 't-' + str(i+1)
    add_time_interval(ts, colname)

# %%
ts = ts[ts.column_names()[::-1]]

# %%
ts.remove_column(name='PM2.5')
# Out:
# Columns:
# 	datetime	datetime (index column)
# 	t-24	float
# 	t-23	float
# 	t-22	float
# 	t-21	float
# 	t-20	float
# 	t-19	float
# 	t-18	float
# 	t-17	float
# 	t-16	float
# 	t-15	float
# 	t-14	float
# 	t-13	float
# 	t-12	float
# 	t-11	float
# 	t-10	float
# 	t-9	float
# 	t-8	float
# 	t-7	float
# 	t-6	float
# 	t-5	float
# 	t-4	float
# 	t-3	float
# 	t-2	float
# 	t-1	float
#
# Rows: 8784
#
# Data:
# +---------------------+------+------+------+------+------+------+------+------+
# |       datetime      | t-24 | t-23 | t-22 | t-21 | t-20 | t-19 | t-18 | t-17 |
# +---------------------+------+------+------+------+------+------+------+------+
# | 2016-01-01 00:00:00 | None | None | None | None | None | None | None | None |
# | 2016-01-01 01:00:00 | None | None | None | None | None | None | None | None |
# | 2016-01-01 02:00:00 | None | None | None | None | None | None | None | None |
# | 2016-01-01 03:00:00 | None | None | None | None | None | None | None | None |
# | 2016-01-01 04:00:00 | None | None | None | None | None | None | None | None |
# | 2016-01-01 05:00:00 | None | None | None | None | None | None | None | None |
# | 2016-01-01 06:00:00 | None | None | None | None | None | None | None | None |
# | 2016-01-01 07:00:00 | None | None | None | None | None | None | None | None |
# | 2016-01-01 08:00:00 | None | None | None | None | None | None | None | None |
# | 2016-01-01 09:00:00 | None | None | None | None | None | None | None | None |
# +---------------------+------+------+------+------+------+------+------+------+
# +------+------+------+------+------+------+------+------+------+------+------+-----+
# | t-16 | t-15 | t-14 | t-13 | t-12 | t-11 | t-10 | t-9  | t-8  | t-7  | t-6  | ... |
# +------+------+------+------+------+------+------+------+------+------+------+-----+
# | None | None | None | None | None | None | None | None | None | None | None | ... |
# | None | None | None | None | None | None | None | None | None | None | None | ... |
# | None | None | None | None | None | None | None | None | None | None | None | ... |
# | None | None | None | None | None | None | None | None | None | None | None | ... |
# | None | None | None | None | None | None | None | None | None | None | None | ... |
# | None | None | None | None | None | None | None | None | None | None | None | ... |
# | None | None | None | None | None | None | None | None | None | None | 66.0 | ... |
# | None | None | None | None | None | None | None | None | None | 66.0 | 56.0 | ... |
# | None | None | None | None | None | None | None | None | 66.0 | 56.0 | 57.0 | ... |
# | None | None | None | None | None | None | None | 66.0 | 56.0 | 57.0 | 65.0 | ... |
# +------+------+------+------+------+------+------+------+------+------+------+-----+
# [8784 rows x 25 columns]
# Note: Only the head of the TimeSeries is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
sf = ts.to_sframe()
df = sf.to_dataframe()

# %%
df.to_csv('../data/pm2.5_timeseries.csv', index=False)
