# %%
import graphlab as gl
import datetime as dt

# %%
def add_time_interval(ts, colname):
    lastcol = ts.column_names()[-1]
    ts.add_column(ts.shift(steps=1)[lastcol], name=colname)
    return ts

# %%
target = 'PM2.5'

# %%
date_feature = gl.SFrame.read_csv("../data/dropna/dropna.csv")
date_feature['datetime'] = date_feature['datetime'].apply(lambda x: dt.datetime.strptime(x, "%Y-%m-%d %H:%M:%S"))
# Out:
# Finished parsing file /Users/jason/Desktop/air-polution/data/dropna/dropna.csv
# Parsing completed. Parsed 100 lines in 0.148297 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[float,float,float,float,float,float,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /Users/jason/Desktop/air-polution/data/dropna/dropna.csv
# Parsing completed. Parsed 82674 lines in 0.157291 secs.

# %%
ts = gl.TimeSeries(date_feature, index='datetime')
ts = ts[[target]]

ts['dlt'] = ts[target] - ts.shift(steps=1)[target]
ts.head()
# Out:
# Columns:
# 	datetime	datetime
# 	PM2.5	float
# 	dlt	float
#
# Rows: 10
#
# Data:
# +---------------------+-------+------+
# |       datetime      | PM2.5 | dlt  |
# +---------------------+-------+------+
# | 2007-01-01 00:00:00 |  18.0 | None |
# | 2007-01-01 01:00:00 |  22.0 | 4.0  |
# | 2007-01-01 02:00:00 |  21.0 | -1.0 |
# | 2007-01-01 03:00:00 |  25.0 | 4.0  |
# | 2007-01-01 04:00:00 |  22.0 | -3.0 |
# | 2007-01-01 05:00:00 |  28.0 | 6.0  |
# | 2007-01-01 06:00:00 |  32.0 | 4.0  |
# | 2007-01-01 07:00:00 |  44.0 | 12.0 |
# | 2007-01-01 08:00:00 |  45.0 | 1.0  |
# | 2007-01-01 09:00:00 |  58.0 | 13.0 |
# +---------------------+-------+------+
# [10 rows x 3 columns]

# %%
interval = 24
for i in range(interval):
    colname = 'dlt-' + str(i+1)
    add_time_interval(ts, colname)

# %%
ts = ts[ts.column_names()[::-1]]

# %%
ts.remove_column(name=target)
# Out:
# Columns:
# 	datetime	datetime (index column)
# 	dlt-24	float
# 	dlt-23	float
# 	dlt-22	float
# 	dlt-21	float
# 	dlt-20	float
# 	dlt-19	float
# 	dlt-18	float
# 	dlt-17	float
# 	dlt-16	float
# 	dlt-15	float
# 	dlt-14	float
# 	dlt-13	float
# 	dlt-12	float
# 	dlt-11	float
# 	dlt-10	float
# 	dlt-9	float
# 	dlt-8	float
# 	dlt-7	float
# 	dlt-6	float
# 	dlt-5	float
# 	dlt-4	float
# 	dlt-3	float
# 	dlt-2	float
# 	dlt-1	float
# 	dlt	float
#
# Rows: 82674
#
# Data:
# +---------------------+--------+--------+--------+--------+--------+--------+
# |       datetime      | dlt-24 | dlt-23 | dlt-22 | dlt-21 | dlt-20 | dlt-19 |
# +---------------------+--------+--------+--------+--------+--------+--------+
# | 2007-01-01 00:00:00 |  None  |  None  |  None  |  None  |  None  |  None  |
# | 2007-01-01 01:00:00 |  None  |  None  |  None  |  None  |  None  |  None  |
# | 2007-01-01 02:00:00 |  None  |  None  |  None  |  None  |  None  |  None  |
# | 2007-01-01 03:00:00 |  None  |  None  |  None  |  None  |  None  |  None  |
# | 2007-01-01 04:00:00 |  None  |  None  |  None  |  None  |  None  |  None  |
# | 2007-01-01 05:00:00 |  None  |  None  |  None  |  None  |  None  |  None  |
# | 2007-01-01 06:00:00 |  None  |  None  |  None  |  None  |  None  |  None  |
# | 2007-01-01 07:00:00 |  None  |  None  |  None  |  None  |  None  |  None  |
# | 2007-01-01 08:00:00 |  None  |  None  |  None  |  None  |  None  |  None  |
# | 2007-01-01 09:00:00 |  None  |  None  |  None  |  None  |  None  |  None  |
# +---------------------+--------+--------+--------+--------+--------+--------+
# +--------+--------+--------+--------+--------+--------+--------+--------+--------+
# | dlt-18 | dlt-17 | dlt-16 | dlt-15 | dlt-14 | dlt-13 | dlt-12 | dlt-11 | dlt-10 |
# +--------+--------+--------+--------+--------+--------+--------+--------+--------+
# |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |
# |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |
# |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |
# |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |
# |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |
# |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |
# |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |
# |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |
# |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |
# |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |  None  |
# +--------+--------+--------+--------+--------+--------+--------+--------+--------+
# +-------+-------+-------+-------+-----+
# | dlt-9 | dlt-8 | dlt-7 | dlt-6 | ... |
# +-------+-------+-------+-------+-----+
# |  None |  None |  None |  None | ... |
# |  None |  None |  None |  None | ... |
# |  None |  None |  None |  None | ... |
# |  None |  None |  None |  None | ... |
# |  None |  None |  None |  None | ... |
# |  None |  None |  None |  None | ... |
# |  None |  None |  None |  None | ... |
# |  None |  None |  None |  4.0  | ... |
# |  None |  None |  4.0  |  -1.0 | ... |
# |  None |  4.0  |  -1.0 |  4.0  | ... |
# +-------+-------+-------+-------+-----+
# [82674 rows x 26 columns]
# Note: Only the head of the TimeSeries is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
sf = ts.to_sframe()
df = sf.to_dataframe()

# %%
df.to_csv('../data/dropna/dlt_timeseries.csv', index=False)
