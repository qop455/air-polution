# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.plotly as py
plt.rcParams['figure.figsize'] = [16.0, 8.0]

# %%
data = pd.read_csv("../data/Erlin.csv", parse_dates=True).fillna(0)

targets = ['RAINFALL', 'RH', 'AMB_TEMP', 'WIND_SPEED', 'WIND_DIREC']

data = data[targets]

# %%
for target in targets:
    plt.hist(data[target], bins=np.arange(0, max(data[target])), rwidth=0.8)
    plt.title(target)
    plt.xlabel('value')
    plt.ylabel('accumulation')
    fig = plt.gcf()
    plt.show()

# %%
coef = pd.read_csv('../output/LR_coefficients.csv')

coef.describe()
# Out:
#        AMB_TEMP  RAINFALL       RH  WIND_SPEED    hour_0    hour_1   hour_10  \
# count  1.000000  1.000000  1.00000     1.00000  1.000000  1.000000  1.000000
# mean  -0.476309 -0.166729 -0.14173    -0.66086 -0.733893 -0.780013  0.613682
# std         NaN       NaN      NaN         NaN       NaN       NaN       NaN
# min   -0.476309 -0.166729 -0.14173    -0.66086 -0.733893 -0.780013  0.613682
# 25%   -0.476309 -0.166729 -0.14173    -0.66086 -0.733893 -0.780013  0.613682
# 50%   -0.476309 -0.166729 -0.14173    -0.66086 -0.733893 -0.780013  0.613682
# 75%   -0.476309 -0.166729 -0.14173    -0.66086 -0.733893 -0.780013  0.613682
# max   -0.476309 -0.166729 -0.14173    -0.66086 -0.733893 -0.780013  0.613682
#
#        hour_11   hour_12   hour_13    ...           t-7      t-8       t-9  \
# count  1.00000  1.000000  1.000000    ...      1.000000  1.00000  1.000000
# mean   0.41823  0.326234  0.000644    ...      0.332652 -0.05185 -0.151192
# std        NaN       NaN       NaN    ...           NaN      NaN       NaN
# min    0.41823  0.326234  0.000644    ...      0.332652 -0.05185 -0.151192
# 25%    0.41823  0.326234  0.000644    ...      0.332652 -0.05185 -0.151192
# 50%    0.41823  0.326234  0.000644    ...      0.332652 -0.05185 -0.151192
# 75%    0.41823  0.326234  0.000644    ...      0.332652 -0.05185 -0.151192
# max    0.41823  0.326234  0.000644    ...      0.332652 -0.05185 -0.151192
#
#        weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  weekday_6  \
# count   1.000000   1.000000   1.000000   1.000000   1.000000    1.00000
# mean    0.039668  -0.096127  -0.047492   0.029965  -0.025275    0.11397
# std          NaN        NaN        NaN        NaN        NaN        NaN
# min     0.039668  -0.096127  -0.047492   0.029965  -0.025275    0.11397
# 25%     0.039668  -0.096127  -0.047492   0.029965  -0.025275    0.11397
# 50%     0.039668  -0.096127  -0.047492   0.029965  -0.025275    0.11397
# 75%     0.039668  -0.096127  -0.047492   0.029965  -0.025275    0.11397
# max     0.039668  -0.096127  -0.047492   0.029965  -0.025275    0.11397
#
#        weekday_7
# count   1.000000
# mean   -0.014709
# std          NaN
# min    -0.014709
# 25%    -0.014709
# 50%    -0.014709
# 75%    -0.014709
# max    -0.014709
#
# [8 rows x 51 columns]

# %%
df_coefs = pd.DataFrame(dict(coef.mean()), index=[0])

df_coefs.describe()
# Out:
#        AMB_TEMP  RAINFALL       RH  WIND_SPEED    hour_0    hour_1   hour_10  \
# count  1.000000  1.000000  1.00000     1.00000  1.000000  1.000000  1.000000
# mean  -0.476309 -0.166729 -0.14173    -0.66086 -0.733893 -0.780013  0.613682
# std         NaN       NaN      NaN         NaN       NaN       NaN       NaN
# min   -0.476309 -0.166729 -0.14173    -0.66086 -0.733893 -0.780013  0.613682
# 25%   -0.476309 -0.166729 -0.14173    -0.66086 -0.733893 -0.780013  0.613682
# 50%   -0.476309 -0.166729 -0.14173    -0.66086 -0.733893 -0.780013  0.613682
# 75%   -0.476309 -0.166729 -0.14173    -0.66086 -0.733893 -0.780013  0.613682
# max   -0.476309 -0.166729 -0.14173    -0.66086 -0.733893 -0.780013  0.613682
#
#        hour_11   hour_12   hour_13    ...           t-7      t-8       t-9  \
# count  1.00000  1.000000  1.000000    ...      1.000000  1.00000  1.000000
# mean   0.41823  0.326234  0.000644    ...      0.332652 -0.05185 -0.151192
# std        NaN       NaN       NaN    ...           NaN      NaN       NaN
# min    0.41823  0.326234  0.000644    ...      0.332652 -0.05185 -0.151192
# 25%    0.41823  0.326234  0.000644    ...      0.332652 -0.05185 -0.151192
# 50%    0.41823  0.326234  0.000644    ...      0.332652 -0.05185 -0.151192
# 75%    0.41823  0.326234  0.000644    ...      0.332652 -0.05185 -0.151192
# max    0.41823  0.326234  0.000644    ...      0.332652 -0.05185 -0.151192
#
#        weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  weekday_6  \
# count   1.000000   1.000000   1.000000   1.000000   1.000000    1.00000
# mean    0.039668  -0.096127  -0.047492   0.029965  -0.025275    0.11397
# std          NaN        NaN        NaN        NaN        NaN        NaN
# min     0.039668  -0.096127  -0.047492   0.029965  -0.025275    0.11397
# 25%     0.039668  -0.096127  -0.047492   0.029965  -0.025275    0.11397
# 50%     0.039668  -0.096127  -0.047492   0.029965  -0.025275    0.11397
# 75%     0.039668  -0.096127  -0.047492   0.029965  -0.025275    0.11397
# max     0.039668  -0.096127  -0.047492   0.029965  -0.025275    0.11397
#
#        weekday_7
# count   1.000000
# mean   -0.014709
# std          NaN
# min    -0.014709
# 25%    -0.014709
# 50%    -0.014709
# 75%    -0.014709
# max    -0.014709
#
# [8 rows x 51 columns]

# %%
plt.bar(range(len(df_coefs.T.values)), df_coefs.T.values, width=0.3, color='C0', alpha=0.8)
plt.axhline(color='C0', xmin=0.01, xmax=0.99, alpha=0.8)
for x in range(len(df_coefs.columns)):
    if df_coefs.T.values[x] > 0.3 :
        plt.text(x + 0.2 , df_coefs.T.values[x] , str(round(df_coefs.T.values[x], 4)), color='k', rotation=90)
    elif df_coefs.T.values[x] < -0.3:
        plt.text(x + 0.2 , df_coefs.T.values[x] + 0.1 , str(round(df_coefs.T.values[x], 4)), color='k', rotation=90)
plt.xticks(range(len(df_coefs.T.values)), df_coefs.columns)
plt.xticks(rotation=90)
plt.title('LR Coefficients')
plt.xlabel('feature')
plt.ylabel('value')
fig = plt.gcf()
plt.show()
